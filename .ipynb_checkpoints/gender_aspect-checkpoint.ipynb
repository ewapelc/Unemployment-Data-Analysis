# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore", "use_inf_as_na")

# %matplotlib inline

# %% [markdown]
# ## Dataset introduction
#
# Here we should put some information about the dataset, such as data source, columns description etc.
#
# Maybe we should put here an introduction on the topic of unemployment, or specify some goals of our analysis

# %% [markdown]
# ## Data Cleaning & Preporcessing

# %%
gender = pd.read_excel('files/gender.xlsx', sheet_name = 1)
gender.head()
# Out:
#    Kod   Nazwa Miesiące    Płeć   Rok  Wartosc Jednostka miary Atrybut
# 0    0  POLSKA  styczeń  ogółem  2011  2104986           osoba
# 1    0  POLSKA  styczeń  ogółem  2012  2121518           osoba
# 2    0  POLSKA  styczeń  ogółem  2013  2295744           osoba
# 3    0  POLSKA  styczeń  ogółem  2014  2260662           osoba
# 4    0  POLSKA  styczeń  ogółem  2015  1918599           osoba

# %%
gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Kod              504 non-null    int64
#  1   Nazwa            504 non-null    object
#  2   Miesiące         504 non-null    object
#  3   Płeć             504 non-null    object
#  4   Rok              504 non-null    int64
#  5   Wartosc          504 non-null    object
#  6   Jednostka miary  504 non-null    object
#  7   Atrybut          504 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.6+ KB

# %%
for col in gender:
    print(f"{col}:\t\t{gender[col].unique()}")
# Out:
# Kod:		[0]
# Nazwa:		['POLSKA']
# Miesiące:		['styczeń' 'luty' 'marzec' 'kwiecień' 'maj' 'czerwiec' 'lipiec' 'sierpień'
#  'wrzesień' 'październik' 'listopad' 'grudzień']
# Płeć:		['ogółem' 'mężczyźni' 'kobiety']
# Rok:		[2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024]
# Wartosc:		[2104986 2121518 2295744 2260662 1918599 1647457 1397115 1133738 1023083
#  922197 1090365 927112 857589 837063 1024535 1009132 1139852 1125271
#  942262 798674 661527 517573 458409 418559 507014 431153 399320 399445
#  1080451 1112386 1155892 1135391 976337 848783 735588 616165 564674 503638
#  583351 495959 458269 437618 2150233 2168156 2336686 2255909 1918727
#  1652656 1383376 1126730 1016702 919865 1099538 921760 864781 '-' 1052380
#  1047194 1174754 1133874 949687 806349 658600 517193 458545 420957 514380
#  430441 404704 1097853 1120962 1161932 1122035 969040 846307 724776 609537
#  558157 498908 585158 491319 460077 2133916 2141906 2314453 2182205
#  1860644 1600455 1324217 1092177 984739 909442 1078443 902091 846868
#  1040218 1039104 1173642 1098258 921992 781406 626112 501043 443287 417771
#  504878 415872 397433 1093698 1102802 1140811 1083947 938652 819049 698105
#  591134 541452 491671 573565 486219 449435 2043516 2072640 2255710 2079049
#  1782181 1521814 1252696 1042545 938280 965798 1053794 877967 821916
#  982979 999071 1141068 1039036 875266 735391 584642 470581 417969 444232
#  490623 400179 384837 1060537 1073569 1114642 1040013 906915 786423 668054
#  571964 520311 521566 563171 477788 437079 1962587 2013936 2176337 1986710
#  1702078 1456873 1202103 1002153 906040 1011689 1026727 850221 802318
#  928431 961469 1088699 985433 827844 695583 552655 445995 399915 466581
#  476054 386206 375114 1034156 1052467 1087638 1001277 874234 761290 649448
#  556158 506125 545108 550673 464015 427204 1883299 1964445 2109145 1912541
#  1622276 1392460 1151647 967900 877093 1026471 993394 818044 783520 874953
#  930823 1044801 939807 780398 655842 521192 424176 382928 475468 458983
#  369881 364829 1008346 1033622 1064344 972734 841878 736618 630455 543724
#  494165 551003 534411 448163 418691 1863175 1953184 2093103 1878520
#  1585667 1361499 1139986 961769 868398 1029507 974870 810231 782449 851050
#  914219 1015663 908360 749102 628742 505622 413842 373279 474505 445783
#  363027 361151 1012125 1038965 1077440 970160 836565 732757 634364 547927
#  495119 555002 529087 447204 421298 1855336 1964706 2083209 1853190
#  1563538 1346868 1136126 958603 865492 1027955 960813 806943 782504 835636
#  912206 999068 885109 730559 613619 495884 407416 368771 470419 435375
#  359318 358975 1019700 1052500 1084141 968081 832979 733249 640242 551187
#  496721 557536 525438 447625 423529 1861689 1978987 2083116 1821948
#  1539371 1324114 1117113 947393 851151 1023746 934674 801666 775987 837116
#  922935 998819 869037 722236 605769 490733 406861 367810 470821 426727
#  362480 359910 1024573 1056052 1084297 952911 817135 718345 626380 540532
#  483341 552925 507947 439186 416077 1867570 1994872 2075163 1784814
#  1516928 1307970 1069515 937339 840518 1018377 910930 796002 770446 841512
#  936881 995168 851942 712495 599170 471416 404019 365012 469425 416271
#  361756 358528 1026058 1057991 1079995 932872 804433 708800 598099 533320
#  475506 548952 494659 434246 411918 1914936 2058142 2116032 1799779
#  1530597 1313620 1067666 950549 849628 1025723 898803 800160 773403 873549
#  979920 1022472 863039 724353 605645 474032 412872 372924 473153 412099
#  366385 362672 1041387 1078222 1093560 936740 806244 707975 593634 537677
#  476704 552570 486704 433775 410731 1982676 2136815 2157883 1825180
#  1563339 1335155 1081746 968888 866374 1046432 895203 812301 788229 922472
#  1037629 1058427 885532 747201 622928 486216 426246 386959 484826 413268
#  375892 373293 1060204 1099186 1099456 939648 816138 712227 595530 542642
#  479415 561606 481935 436409 414936]
# Jednostka miary:		['osoba']
# Atrybut:		[' ' 'n']

# %%
gender[gender['Atrybut'] == 'n']['Rok'].unique()
# Out:
# array([2024], dtype=int64)

# %%
gender[gender['Wartosc'] == '-'] == gender[gender['Atrybut'] == 'n']
# Out:
#       Kod  Nazwa  Miesiące  Płeć   Rok  Wartosc  Jednostka miary  Atrybut
# 55   True   True      True  True  True     True             True     True
# 69   True   True      True  True  True     True             True     True
# 83   True   True      True  True  True     True             True     True
# 97   True   True      True  True  True     True             True     True
# 111  True   True      True  True  True     True             True     True
# 125  True   True      True  True  True     True             True     True
# 139  True   True      True  True  True     True             True     True
# 153  True   True      True  True  True     True             True     True
# 167  True   True      True  True  True     True             True     True
# 181  True   True      True  True  True     True             True     True
# 195  True   True      True  True  True     True             True     True
# 209  True   True      True  True  True     True             True     True
# 223  True   True      True  True  True     True             True     True
# 237  True   True      True  True  True     True             True     True
# 251  True   True      True  True  True     True             True     True
# 265  True   True      True  True  True     True             True     True
# 279  True   True      True  True  True     True             True     True
# 293  True   True      True  True  True     True             True     True
# 307  True   True      True  True  True     True             True     True
# 321  True   True      True  True  True     True             True     True
# 335  True   True      True  True  True     True             True     True
# 349  True   True      True  True  True     True             True     True
# 363  True   True      True  True  True     True             True     True
# 377  True   True      True  True  True     True             True     True
# 391  True   True      True  True  True     True             True     True
# 405  True   True      True  True  True     True             True     True
# 419  True   True      True  True  True     True             True     True
# 433  True   True      True  True  True     True             True     True
# 447  True   True      True  True  True     True             True     True
# 461  True   True      True  True  True     True             True     True
# 475  True   True      True  True  True     True             True     True
# 489  True   True      True  True  True     True             True     True
# 503  True   True      True  True  True     True             True     True

# %%
gender = gender[gender['Atrybut'] != 'n']
gender.drop(['Kod', 'Nazwa', 'Jednostka miary', 'Atrybut'], axis = 1, inplace = True)
gender.head()
# Out:
#   Miesiące    Płeć   Rok  Wartosc
# 0  styczeń  ogółem  2011  2104986
# 1  styczeń  ogółem  2012  2121518
# 2  styczeń  ogółem  2013  2295744
# 3  styczeń  ogółem  2014  2260662
# 4  styczeń  ogółem  2015  1918599

# %%
gender.head()
# Out:
#   Miesiące    Płeć   Rok  Wartosc
# 0  styczeń  ogółem  2011  2104986
# 1  styczeń  ogółem  2012  2121518
# 2  styczeń  ogółem  2013  2295744
# 3  styczeń  ogółem  2014  2260662
# 4  styczeń  ogółem  2015  1918599

# %%
month_mapping = {
    'styczeń' : 1,
    'luty' : 2,
    'marzec' : 3,
    'kwiecień' : 4,
    'maj' : 5,
    'czerwiec' : 6,
    'lipiec' : 7,
    'sierpień' : 8,
    'wrzesień' : 9,
    'październik' : 10,
    'listopad' : 11,
    'grudzień' : 12
}

# %%
gender['month'] = gender['Miesiące'].map(month_mapping)

# %%
gender.rename(columns = {'Rok' : 'year', 'mnth_num' : 'month'}, inplace = True)

# %%
gender['Data'] = pd.to_datetime(gender[['year', 'month']].assign(DAY=1))
gender.head()
# Out:
#   Miesiące    Płeć  year  Wartosc  month       Data
# 0  styczeń  ogółem  2011  2104986      1 2011-01-01
# 1  styczeń  ogółem  2012  2121518      1 2012-01-01
# 2  styczeń  ogółem  2013  2295744      1 2013-01-01
# 3  styczeń  ogółem  2014  2260662      1 2014-01-01
# 4  styczeń  ogółem  2015  1918599      1 2015-01-01

# %%
gender = gender[['Płeć', 'Wartosc', 'Data']]
gender.head()
# Out:
#      Płeć  Wartosc       Data
# 0  ogółem  2104986 2011-01-01
# 1  ogółem  2121518 2012-01-01
# 2  ogółem  2295744 2013-01-01
# 3  ogółem  2260662 2014-01-01
# 4  ogółem  1918599 2015-01-01

# %% [markdown]
# ## EDA

# %%
fig = plt.figure(figsize = [12,8])

sns.lineplot(x="Data", y="Wartosc",
             hue="Płeć",
             data=gender)

# ax.axhline(y=np.mean(gender[gender["Płeć"] == 'kobiety']['Wartosc']), color='green', linestyle='--', label='Linia dodatkowa')
# Out:
# <Axes: xlabel='Data', ylabel='Wartosc'>

# %%
gender.isin([np.inf, -np.inf]).any()
# Out:
# Płeć       False
# Wartosc    False
# Data       False
# dtype: bool

# %%
gender['Wartosc'] = gender.Wartosc.astype(int)

# %%
fig = plt.figure(figsize = [12,8])

sns.swarmplot(data=gender, x="Płeć", y="Wartosc", hue="Płeć")
# Out:
# <Axes: xlabel='Płeć', ylabel='Wartosc'>
